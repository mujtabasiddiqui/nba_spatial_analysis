# %%
import pandas as pd

data = pd.read_csv(r'Desktop/Waterloo/3 Spring/GEOG 481/RAPM.csv')

# %%
data.sort_values(['playerId','season'], ascending = True)
# Out:
#       playerId     playerName  RAPM     season      teamId teamName  \
# 1897       255     Grant Hill -0.02  2010-2011  1610612756      PHX
# 1370       255     Grant Hill  1.17  2011-2012  1610612756      PHX
# 545        255     Grant Hill -1.59    2012-13  1610612746      LAC
# 3607       436   Juwan Howard -0.23  2010-2011  1610612748      MIA
# 1672       436   Juwan Howard -1.84  2011-2012  1610612748      MIA
# ...        ...            ...   ...        ...         ...      ...
# 2720   1629744    Matt Thomas -0.12    2019-20  1610612761      TOR
# 354    1629745    Tariq Owens -0.27    2019-20  1610612756      PHX
# 2721   1629750  Javonte Green -0.45    2019-20  1610612738      BOS
# 2722   1629752   Juwan Morgan  0.45    2019-20  1610612762      UTA
# 1689   1629760    Matt Mooney  0.07    2019-20  1610612739      CLE
#
#            primaryKey
# 1897      255_2010-11
# 1370      255_2011-12
# 545       255_2012-13
# 3607      436_2010-11
# 1672      436_2011-12
# ...

# %%
data.describe() #To get RAPM mean value 10 season means
# Out:
#            playerId         RAPM        teamId
# count  4.866000e+03  4866.000000  4.866000e+03
# mean   4.525155e+05     0.003859  1.441144e+09
# std    5.970931e+05     1.659816  4.942456e+08
# min    2.550000e+02    -6.550000 -1.000000e+00
# 25%    2.007970e+05    -0.970000  1.610613e+09
# 50%    2.023790e+05    -0.080000  1.610613e+09
# 75%    2.039208e+05     0.850000  1.610613e+09
# max    1.629760e+06     7.410000  1.610613e+09

# %%
import pandas as pd

data = pd.read_csv(r'Desktop/Waterloo/3 Spring/GEOG 481/RAPM.csv')    

chart_data = data.loc[data["playerName"]== "LeBron James"] #This is where we could have use input player name? Need to ask Muj
final_chart_data = chart_data.sort_values("season")
print(final_chart_data)
# Out:
#       playerId    playerName  RAPM     season      teamId teamName  \
# 1880      2544  LeBron James  4.68  2010-2011  1610612748      MIA
# 1592      2544  LeBron James  4.05  2011-2012  1610612748      MIA
# 740       2544  LeBron James  5.39    2012-13  1610612748      MIA
# 2103      2544  LeBron James  2.77    2013-14  1610612748      MIA
# 1076      2544  LeBron James  6.68    2014-15  1610612739      CLE
# 4337      2544  LeBron James  3.68    2015-16  1610612739      CLE
# 2276      2544  LeBron James  5.86    2016-17  1610612739      CLE
# 1903      2544  LeBron James  2.07    2017-18  1610612739      CLE
# 4507      2544  LeBron James  3.32    2018-19  1610612747      LAL
# 2904      2544  LeBron James  3.96    2019-20  1610612747      LAL
#
#         primaryKey
# 1880  2544_2010-11
# 1592  2544_2011-12
# 740   2544_2012-13
# 2103  2544_2013-14
# 1076  2544_2014-15
# 4337  2544_2015-16
# 2276  2544_2016-17
# 1903  2544_2017-18
# 4507  2544_2018-19
# 2904  2544_2019-20

# %%
import matplotlib.pyplot as plt

chart_data = data.loc[data["playerName"]== "LeBron James"] 
final_chart_data = chart_data.sort_values("season")
final_chart_data.plot(x ='season', y='RAPM', kind = 'line') 
#Need to add in average 
# Possible way to compare two players
